# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionales2026/blob/main/Semana2/Graficacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# como genero una particion equiespaciada
x = np.linspace(0.,5.,100) # X0, XF N
x
# Out:
# array([0.        , 0.05050505, 0.1010101 , 0.15151515, 0.2020202 ,
#        0.25252525, 0.3030303 , 0.35353535, 0.4040404 , 0.45454545,
#        0.50505051, 0.55555556, 0.60606061, 0.65656566, 0.70707071,
#        0.75757576, 0.80808081, 0.85858586, 0.90909091, 0.95959596,
#        1.01010101, 1.06060606, 1.11111111, 1.16161616, 1.21212121,
#        1.26262626, 1.31313131, 1.36363636, 1.41414141, 1.46464646,
#        1.51515152, 1.56565657, 1.61616162, 1.66666667, 1.71717172,
#        1.76767677, 1.81818182, 1.86868687, 1.91919192, 1.96969697,
#        2.02020202, 2.07070707, 2.12121212, 2.17171717, 2.22222222,
#        2.27272727, 2.32323232, 2.37373737, 2.42424242, 2.47474747,
#        2.52525253, 2.57575758, 2.62626263, 2.67676768, 2.72727273,
#        2.77777778, 2.82828283, 2.87878788, 2.92929293, 2.97979798,
#        3.03030303, 3.08080808, 3.13131313, 3.18181818, 3.23232323,
#        3.28282828, 3.33333333, 3.38383838, 3.43434343, 3.48484848,
# ...

# %%
for i in range(0,x.shape[0]-1):
  print(x[i+1]-x[i])
# Out:
# 0.050505050505050504
# 0.050505050505050504
# 0.05050505050505051
# 0.0505050505050505
# 0.050505050505050525
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.05050505050505055
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.0505050505050505
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.050505050505050386
# 0.05050505050505061
# 0.05050505050505061
# 0.050505050505050164
# 0.05050505050505061
# 0.05050505050505061
# 0.05050505050505061
# 0.050505050505050164
# ...

# %%
#INventesmos una function
# Cuando usamos python los grados -> radianes
def f(x):
  return x**2 + x

# %%
# Error de redondeo -> mantiza hasta 1e-16
np.tan(180*np.pi)
# Out:
# np.float64(-7.832787669450353e-15)

# %%
y = f(x)
y
# Out:
# array([ 0.        ,  0.05305581,  0.11121314,  0.17447199,  0.24283236,
#         0.31629426,  0.39485767,  0.4785226 ,  0.56728905,  0.66115702,
#         0.76012652,  0.86419753,  0.97337006,  1.08764412,  1.20701969,
#         1.33149679,  1.4610754 ,  1.59575554,  1.73553719,  1.88042037,
#         2.03040506,  2.18549128,  2.34567901,  2.51096827,  2.68135904,
#         2.85685134,  3.03744516,  3.2231405 ,  3.41393735,  3.60983573,
#         3.81083563,  4.01693705,  4.22813999,  4.44444444,  4.66585042,
#         4.89235792,  5.12396694,  5.36067748,  5.60248954,  5.84940312,
#         6.10141822,  6.35853484,  6.62075298,  6.88807265,  7.16049383,
#         7.43801653,  7.72064075,  8.00836649,  8.30119376,  8.59912254,
#         8.90215284,  9.21028466,  9.52351801,  9.84185287, 10.16528926,
#        10.49382716, 10.82746659, 11.16620753, 11.51004999, 11.85899398,
#        12.21303949, 12.57218651, 12.93643506, 13.30578512, 13.68023671,
# ...

# %%
plt.plot(x,y)

# %%
# Dibujar la recta tangente en el punto x=3

# %%
def recta(x):
  return 5*x - 10

# %%
y1 = recta(x)

# %%
plt.plot(x,y)
plt.plot(x,y1)

# %%
y
# Out:
# array([ 0.        ,  0.05305581,  0.11121314,  0.17447199,  0.24283236,
#         0.31629426,  0.39485767,  0.4785226 ,  0.56728905,  0.66115702,
#         0.76012652,  0.86419753,  0.97337006,  1.08764412,  1.20701969,
#         1.33149679,  1.4610754 ,  1.59575554,  1.73553719,  1.88042037,
#         2.03040506,  2.18549128,  2.34567901,  2.51096827,  2.68135904,
#         2.85685134,  3.03744516,  3.2231405 ,  3.41393735,  3.60983573,
#         3.81083563,  4.01693705,  4.22813999,  4.44444444,  4.66585042,
#         4.89235792,  5.12396694,  5.36067748,  5.60248954,  5.84940312,
#         6.10141822,  6.35853484,  6.62075298,  6.88807265,  7.16049383,
#         7.43801653,  7.72064075,  8.00836649,  8.30119376,  8.59912254,
#         8.90215284,  9.21028466,  9.52351801,  9.84185287, 10.16528926,
#        10.49382716, 10.82746659, 11.16620753, 11.51004999, 11.85899398,
#        12.21303949, 12.57218651, 12.93643506, 13.30578512, 13.68023671,
# ...
